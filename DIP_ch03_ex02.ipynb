# %% [markdown]
# <a href="https://colab.research.google.com/github/luckguy/DIP2001/blob/main/DIP_ch03_ex02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %% [markdown]
# 讀入影像並顯示

# %%
url='https://github.com/opencv/opencv/blob/master/samples/data/messi5.jpg?raw=true'
img=io.imread(url)
plt.figure(dpi=150)
plt.figure
fig=plt.imshow(img)
aa=plt.axis('off')

# %% [markdown]
# 轉成灰階，計算頻譜

# %%
gray_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)/255.
#%% 計算頻譜, 並取 log
f = np.fft.fft2(gray_image)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift)+1)

# %% [markdown]
# 顯示影像與頻譜

# %%
plt.subplot(121)
plt.imshow(gray_image,cmap='gray')
fig=plt.gcf()
fig.set_size_inches(18,12) #變更顯示大小
plt.title('Input Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap ='gray')
plt.title('Magnitude Spectrum'), plt.xticks([]), plt.yticks([])
plt.show()
