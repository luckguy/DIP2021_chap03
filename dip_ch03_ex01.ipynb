# %% [markdown]
# <a href="https://colab.research.google.com/github/luckguy/DIP2001/blob/main/dip_ch03_ex01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 範例 3-1 : Gamma 校正

# %%
import cv2
import numpy as np
import imutils
import matplotlib.pyplot as plt

# %% [markdown]
# 讀入影像

# %%
url='https://sipi.usc.edu/database/preview/misc/boat.512.png'
img=imutils.url_to_image(url)
plt.figure(figsize=(14, 14), dpi=100)
fig=plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 199.5, 199.5, -0.5)

# %% [markdown]
# 利用**指數運算**進行 Gamma 校正

# %%
gamma=2
gray_img1=img/255.   # 正規化
corrected1=np.power(gray_img1,gamma)
corrected2=np.power(gray_img1,1/gamma)

plt.figure(figsize=(16,16),dpi=100)
plt.subplot(131)
plt.imshow(img)
plt.title('Original')
plt.axis('off')
plt.subplot(132)
plt.imshow(corrected1)
plt.title(r'$\gamma =2$')
plt.axis('off')
plt.subplot(133)
plt.imshow(corrected2)
plt.title(r'$\gamma= 1/2$')
plt.axis('off')
# Out:
# (-0.5, 199.5, 199.5, -0.5)
